# %% [markdown]
# ## Testing the speed difference between ExLlamaV2 vs Orthodox Transformer

# %%
# !apt update

# %%
# !pip install --upgrade transformers safetensors sentencepiece huggingface-hub protobuf accelerate bitsandbytes tqdm openai backoff retrying ipykernel ipywidgets matplotlib cmake scikit-build-core setuptools
# Out:
# Requirement already satisfied: transformers in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (4.57.1)
# Requirement already satisfied: safetensors in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (0.7.0)
# Requirement already satisfied: sentencepiece in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (0.2.1)
# Requirement already satisfied: huggingface-hub in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (0.36.0)
# Collecting huggingface-hub
#   Using cached huggingface_hub-1.1.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: protobuf in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (6.33.1)
# Requirement already satisfied: accelerate in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (1.12.0)
# Requirement already satisfied: bitsandbytes in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (0.48.2)
# Requirement already satisfied: tqdm in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (4.67.1)
# Requirement already satisfied: openai in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (2.8.1)
# Requirement already satisfied: backoff in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (2.2.1)
# Requirement already satisfied: retrying in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (1.4.2)
# Requirement already satisfied: ipykernel in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (7.1.0)
# Requirement already satisfied: ipywidgets in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (8.1.8)
# Requirement already satisfied: matplotlib in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: cmake in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (4.2.0)
# Requirement already satisfied: scikit-build-core in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (0.11.6)
# Requirement already satisfied: setuptools in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (80.9.0)
# Requirement already satisfied: filelock in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: fsspec>=2023.5.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from huggingface-hub) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: psutil in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from accelerate) (2.9.1+cu128)
# Requirement already satisfied: sympy>=1.13.3 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: colorama in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: comm>=0.1.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pathspec>=0.10.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from scikit-build-core) (0.12.1)
# Requirement already satisfied: tomli>=1.2.2 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from scikit-build-core) (2.3.0)
# Requirement already satisfied: decorator in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.0)
# Requirement already satisfied: six>=1.5 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: executing>=1.2.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in g:\documents\schools\university\ui\sem_12\ta\aristotle\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Loading exllamav2_ext extension (JIT)...
#
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Loading translation file:  manual_prompts_translated\ProntoQA\naive_prompting_explanations_before_answer.txt
# SAMPLE PCT: 1
# START INDEX: None type: <class 'NoneType'>
# Loaded 5 examples from dev split.
# Number of batch:  1
# Running example id:  ProntoQA_1
#
# Naive prompting: Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
#
# --- Loading Model: LLM_MODELS/llama3-8b-cpt-sahabatai-v1-instruct (hf) ---
#
# Naive prompting response: [SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.
#
# [USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**:
#
# Extracted answer:  False
# Extracted explanations:  ['Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**:']
# Running example id: Saving output for record: {'id': 'ProntoQA_1', 'answer': 'False', 'final_choice': 'B', 'explanations': ['Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**:'], 'ground_truth': 'B', 'response': '[SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.\n\n[USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.\n\n------\n\nContoh:\n\nKonteks:\nImpuses adalah besar. Alex adalah impus.\n\nPertanyaan:\nAlex besar\n\n###\n**Penjelasan**:\nAlex adalah impus.\nImpuses adalah besar.\nAlex adalah besar.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap numpus adalah tembus pandang. Fae adalah numpus.\n\nPertanyaan:\nFae tidak tembus pandang\n\n###\n**Penjelasan**:\nFae adalah numpus.\nSetiap numpus berwarna merah.\nFae adalah tembus pandang\n\n**Jawaban**: False \n###\n\n------\n\n\nContoh:\n\nKonteks:\nWumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.\n\nPertanyaan:\nAlex oranye\n\n###\n**Penjelasan**:\nAlex adalah wumpus.\nWumpuses adalah yumpuses.\nAlex adalah yumpus\nSetiap yumpus berwarnya oranye.\nAlex berwarna oranye.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah b ...
# ProntoQA_2
#
# Naive prompting: Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Setiap tumpus tidak marah. Tumpuses adalah rompuses. Setiap numpus tidak cerah. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.
#
# Pertanyaan:
# Stella cerah.
#
# ###
# **Penjelasan**:
#
# Saving result with thread lock in path:  results_translated_naive_prompting/prompt_explanations_before_answer\ProntoQA\LLM_MODELS_llama3-8b-cpt-sahabatai-v1-instruct_naive_prompting.json
#
# Naive prompting response: [SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.
#
# [USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Setiap tumpus tidak marah. Tumpuses adalah rompuses. Setiap numpus tidak cerah. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.
#
# Pertanyaan:
# Stella cerah.
#
# ###
# **Penjelasan**:
# Stella adalah yumpus.
# Setiap yumpus adalah zumpus.
# Stella adalah zumpus.
# Setiap zumpus tidak pahit.
# Stella tidak pahit.
# Zumpuses adalah impuses.
# Stella adalah impus.
# Setiap impus berwarna merah.
# Stella berwarna merah.
# Impuses adalah vumpuses.
# Stella adalah vumpus.
# Setiap vumpus cerah.
# Stella cerah.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.
#
# Pertanyaan:
# Stella berwarna merah.
#
# ###
# **Penjelasan**:
# Stella adalah yumpus.
# Setiap yumpus adalah zumpus.
# Stella adalah zumpus.
# Setiap zumpus tidak pahit.
# Stella tidak pahit.
# Zumpuses adalah impuses.
# Stella adalah impus.
# Setiap impus berwarna merah.
# Stella berwarna merah.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.
#
# Pertanyaan:
# Stella tidak pahit.
#
# ###
# **Penjelasan**:
# Stella adalah yumpus.
# Setiap yumpus adalah zumpus.
# Stella adalah zumpus.
# Setiap zumpus tidak pahit.
# Stella tidak pahit.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercah
#
# Extracted answer:  True
# Extracted explanations:  ['Stella adalah yumpus.', 'Setiap yumpus adalah zumpus.', 'Stella adalah zumpus.', 'Setiap zumpus tidak pahit.', 'Stella tidak pahit.', 'Zumpuses adalah impuses.', 'Stella adalah impus.', 'Setiap impus berwarna merah.', 'Stella berwarna merah.', 'Impuses adalah vumpuses.', 'Stella adalah vumpus.', 'Setiap vumpus cerah.', 'Stella cerah.', 'Jawaban**: True', '###', 'Contoh:', 'Konteks:', 'Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.', 'Pertanyaan:', 'Stella berwarna merah.', '###', 'Penjelasan**:', 'Stella adalah yumpus.', 'Setiap yumpus adalah zumpus.', 'Stella adalah zumpus.', 'Setiap zumpus tidak pahit.', 'Stella tidak pahit.', 'Zumpuses adalah impuses.', 'Stella adalah impus.', 'Setiap impus berwarna merah.', 'Stella berwarna merah.', 'Jawaban**: True', '###', 'Contoh:', 'Konteks:', 'Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.', 'Pertanyaan:', 'Stella tidak pahit.', '###', 'Penjelasan**:', 'Stella adalah yumpus.', 'Setiap yumpus adalah zumpus.', 'Stella adalah zumpus.', 'Setiap zumpus tidak pahit.', 'Stella tidak pahit.', 'Jawaban**: True', '###', 'Contoh:', 'Konteks:', 'Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercah']
# Running example id: Saving output for record: {'id': 'ProntoQA_2', 'answer': 'True', 'final_choice': 'A', 'explanations': ['Stella adalah yumpus.', 'Setiap yumpus adalah zumpus.', 'Stella adalah zumpus.', 'Setiap zumpus tidak pahit.', 'Stella tidak pahit.', 'Zumpuses adalah impuses.', 'Stella adalah impus.', 'Setiap impus berwarna merah.', 'Stella berwarna merah.', 'Impuses adalah vumpuses.', 'Stella adalah vumpus.', 'Setiap vumpus cerah.', 'Stella cerah.', 'Jawaban**: True', '###', 'Contoh:', 'Konteks:', 'Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.', 'Pertanyaan:', 'Stella berwarna merah.', '###', 'Penjelasan**:', 'Stella adalah yumpus.', 'Setiap yumpus adalah zumpus.', 'Stella adalah zumpus.', 'Setiap zumpus tidak pahit.', 'Stella tidak pahit.', 'Zumpuses adalah impuses.', 'Stella adalah impus.', 'Setiap impus berwarna merah.', 'Stella berwarna merah.', 'Jawaban**: True', '###', 'Contoh:', 'Konteks:', 'Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercahaya. Rompuses adalah yumpuses. Yumpuses adalah transparan. Yumpuses adalah zumpuses. Setiap zumpus tidak pahit. Zumpuses adalah impuses. Impuses berwarna merah. Setiap impus adalah dumpus. Setiap dumpus bahagia. Setiap dumpus adalah vumpus. Vumpuses cerah. Setiap vumpus adalah jompus. Jompuses besar. Setiap jompus adalah wumpus. Stella adalah yumpus.', 'Pertanyaan:', 'Stella tidak pahit.', '###', 'Penjelasan**:', 'Stella adalah yumpus.', 'Setiap yumpus adalah zumpus.', 'Stella adalah zumpus.', 'Setiap zumpus tidak pahit.', 'Stella tidak pahit.', 'Jawaban**: True', '###', 'Contoh:', 'Konteks:', 'Setiap numpus tidak cerah. Numpuses adalah rompuses. Rompuses tidak bercah'], 'ground_truth': 'A', 'response': '[SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.\n\n[USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.\n\n------\n\nContoh:\n\nKonteks:\nImpuses adalah besar. Alex adalah impus.\n\nPertanyaan:\nAlex besar\n\n###\n**Penjelasan**:\nAlex adalah impus.\nImpuses adalah besar.\nAlex adalah besar.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap numpus adalah tembus pandang. Fae adalah numpus.\n\nPertanyaan:\nFae tidak tembus pandang\n\n###\n**Penjelasan**:\nFae adalah numpus.\nSetiap numpus berwarna merah.\nFae adalah tembus pandang\n\n**Jawaban**: False \n###\n\n------\n\n\nContoh:\n\nKonteks:\nWumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.\n\nPertanyaan:\nAlex oranye\n\n###\n**Penjelasan**:\nAlex adalah wumpus.\nWumpuses adalah yumpuses.\nAlex adalah yumpus\nSetiap yumpus berwarnya oranye.\nAlex berwarna oranye.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuse ...
# ProntoQA_3
#
# Naive prompting: Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Vumpuses adalah bunga. Vumpuses adalah tumpuses. Tumpuses berwarna coklat. Setiap tumpus adalah wumpus. Wumpuses kecil. Setiap wumpus adalah rompus. Setiap zumpus adalah logam. Setiap rompus bahagia. Rompuses adalah impuses. Setiap impus ramah. Setiap impus adalah dumpus. Setiap dumpus bukan logam. Dumpuses adalah numpuses. Setiap numpus pahit. Setiap numpus adalah jompus. Setiap jompus dingin. Setiap jompus adalah yumpus. Wren adalah tumpus.
#
# Pertanyaan:
# Wren bukan logam.
#
# ###
# **Penjelasan**:
#
# Saving result with thread lock in path:  results_translated_naive_prompting/prompt_explanations_before_answer\ProntoQA\LLM_MODELS_llama3-8b-cpt-sahabatai-v1-instruct_naive_prompting.json
# g:\Documents\Schools\University\UI\Sem_12\TA\Aristotle\venv\lib\site-packages\setuptools\_distutils\_msvccompiler.py:12: UserWarning: _get_vc_env is private; find an alternative (pypa/distutils#340)
#   warnings.warn(
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:03<00:10,  3.39s/it]
#
# Loading checkpoint shards:  50%|█████     | 2/4 [00:05<00:05,  2.92s/it]
#
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:22<00:09,  9.27s/it]
#
# Loading checkpoint shards: 100%|██████████| 4/4 [00:30<00:00,  8.73s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:30<00:00,  7.67s/it]
#
#  20%|██        | 1/5 [12:58<51:53, 778.30s/it]
#  40%|████      | 2/5 [25:45<38:35, 771.99s/it]

# %%
# !pip install vllm

# %%
# !pip install llama-cpp-python \
    --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu121 \
    --force-reinstall

# %%
# !pip install "numpy<2.3"

# %%
#!pip install --no-cache-dir --upgrade torch torchvision --index-url https://download.pytorch.org/whl/cu128

# %%
# !apt install git-lfs

# %%
import os
import sys

os.environ["TOKENIZERS_PARALLELISM"] = "false"
# ######### Also useful to reduce thread contention:
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["GIT_LFS_SKIP_SMUDGE"] = "1"

# %%
# !git lfs install

# %%
# !git clone https://huggingface.co/Qwen/Qwen2.5-7B-Instruct LLM_MODELS/Qwen2.5-7B-Instruct

# %%
# !git clone https://huggingface.co/Qwen/Qwen2.5-7B-Instruct-GGUF LLM_MODELS_GGUF/Qwen2.5-7B-Instruct-GGUF

# %%
# !cd LLM_MODELS_GGUF/Qwen2.5-7B-Instruct-GGUF && git lfs pull --include "*q4_k_m*"

# %%
# 1. Download the official pre-built binaries (Ubuntu x64)
print("Downloading llama.cpp CLI tools...")
# !wget -q https://github.com/ggml-org/llama.cpp/releases/download/b7134/llama-b7134-bin-ubuntu-x64.zip -O llama_tools.zip

# 2. Unzip into a specific folder
print("Extracting...")
# !unzip -o -q llama_tools.zip -d llama_tools_bin

# 3. Make the splitter executable
tool_path = os.path.abspath("llama_tools_bin/build/bin/llama-gguf-split")
# !chmod +x {tool_path}

# 4. Add to PATH environment variable so you can use '!' commands
if "llama_tools_bin/build/bin" not in os.environ["PATH"]:
    os.environ["PATH"] += os.pathsep + os.path.dirname(tool_path)

print(f"Installed tools to: {os.path.dirname(tool_path)}")

# 5. Verify it works
print("\nVerifying llama-gguf-split version:")
# !llama-gguf-split --help | head -n 5

# %%
# !llama-gguf-split --merge LLM_MODELS_GGUF/Qwen2.5-7B-Instruct-GGUF/qwen2.5-7b-instruct-q4_k_m-00001-of-00002.gguf LLM_MODELS_GGUF/Qwen2.5-7B-Instruct-GGUF/qwen2.5-7b-instruct-q4_k_m.gguf

# %%
from misc.speed_test_backend import BenchmarkConfig, run_benchmark

config = BenchmarkConfig(
    model_path="LLM_MODELS/Qwen2.5-7B-Instruct",
    backend="hf",
    quantize_4bit=True,
)

results = run_benchmark(config)

config = BenchmarkConfig(
    model_path="LLM_MODELS/Qwen2.5-7B-Instruct",
    backend="vllm",
    quantization="fp8",
)

results = run_benchmark(config)

config = BenchmarkConfig(
    model_path="LLM_MODELS_GGUF/Qwen2.5-7B-Instruct-GGUF/qwen2.5-7b-instruct-q4_k_m.gguf",
    backend="llamacpp",
)

results = run_benchmark(config)

# %% [markdown]
# ### On specific dataset and prompt

# %%
import os
import sys

# %%
# Commandline args universal
# MAX_NEW_TOKENS is purely for text generation count limit while max_position_embeddings is for context_length based on LLM config.json. !!! input_length + MAX_NEW_TOKENS shopuld be < context_length, otherwise LLM breaks. Llama 3 only has 8k context length/max_posiiton_embedding. SEALIONv3-LLama3-8B-IT uses ROPE, max_position_embeddings follows ROPE limit 131k, Qwen2.5-7B-IT has 32k context length, SahabatAIv1-LLama3-8B-IT has 8k context length.
# Counted the response for each steps in notebook output cell with tokens counter online, translations ~400 tokens, ~decomposition ~500 tokens, search_resolve ~700 tokens
# Change this every process (translate, decompose, search_resolve), different value is needed. Time is in seconds.
os.environ["LLM_WORKER_MAX_TIME"] = "300"
LLM_WORKER_MAX_TIME=300
os.environ["MAX_NEW_TOKENS"] = "1200"
MAX_NEW_TOKENS=1200
os.environ["BATCH_NUM"] = "1"
BATCH_NUM=1

print("LLM_WORKER_MAX_TIME =", os.environ["LLM_WORKER_MAX_TIME"])
print("MAX_NEW_TOKENS =", os.environ["MAX_NEW_TOKENS"])
print("BATCH_NUM =", os.environ["BATCH_NUM"])
# Out:
# LLM_WORKER_MAX_TIME = 300
# MAX_NEW_TOKENS = 1200
# BATCH_NUM = 1

# %%
os.environ["LLM_BACKEND"] = "hf"

snapshot_path = "LLM_MODELS/llama3-8b-cpt-sahabatai-v1-instruct"
#snapshot_path = "/workspace/LLM_MODELS/Llama-SEA-LION-v3-8B-IT"

os.environ["LOCAL_MODEL_PATH"] = snapshot_path
os.environ["LLM_MODEL"] = snapshot_path

os.environ["LLM_LOAD_IN_4BIT"] = "1"  # or "0" to disable quantization
print("LOCAL_MODEL_PATH =", os.environ["LOCAL_MODEL_PATH"])
print("LLM_MODEL =", os.environ["LLM_MODEL"])

### If kernel doesnt recognize
LLM_MODEL=snapshot_path
LOCAL_MODEL_PATH=snapshot_path
# Out:
# LOCAL_MODEL_PATH = LLM_MODELS/llama3-8b-cpt-sahabatai-v1-instruct
# LLM_MODEL = LLM_MODELS/llama3-8b-cpt-sahabatai-v1-instruct

# %%
# Naive prompting only requires True or False answer based on context
os.environ["MAX_NEW_TOKENS"] = "600"
MAX_NEW_TOKENS=600
os.environ["BATCH_NUM"] = "1"
BATCH_NUM=1

# %%
# Solving with naive prompting with explanations only
# !python naive_prompting.py --data_path results_bahasa_translation --dataset_name ProntoQA --sample_pct 0 --prompts_folder manual_prompts_translated --prompts_file naive_prompting_explanations_before_answer --split dev --save_path results_translated_naive_prompting/prompt_explanations_before_answer --model_name $LLM_MODEL --batch_num $BATCH_NUM --max_new_tokens $MAX_NEW_TOKENS
# Out:
# Loading exllamav2_ext extension (JIT)...
#
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Loading translation file:  manual_prompts_translated\ProntoQA\naive_prompting_explanations_before_answer.txt
# SAMPLE PCT: 0
# START INDEX: None type: <class 'NoneType'>
# Loaded 1 examples from dev split.
# Number of batch:  1
# Running example id:  ProntoQA_1
#
# Naive prompting: Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
#
# --- Loading Model: LLM_MODELS/llama3-8b-cpt-sahabatai-v1-instruct (hf) ---
#
# Naive prompting response: [SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.
#
# [USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**:
#
# Extracted answer:  False
# Extracted explanations:  ['Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**:']
# Saving output for record: {'id': 'ProntoQA_1', 'answer': 'False', 'final_choice': 'B', 'explanations': ['Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**: Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpuses.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpuses.', 'Max juga tumpus', 'Tumpuses tidak asam.', 'Max tidak asam.', 'Jawaban**:'], 'ground_truth': 'B', 'response': '[SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.\n\n[USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.\n\n------\n\nContoh:\n\nKonteks:\nImpuses adalah besar. Alex adalah impus.\n\nPertanyaan:\nAlex besar\n\n###\n**Penjelasan**:\nAlex adalah impus.\nImpuses adalah besar.\nAlex adalah besar.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap numpus adalah tembus pandang. Fae adalah numpus.\n\nPertanyaan:\nFae tidak tembus pandang\n\n###\n**Penjelasan**:\nFae adalah numpus.\nSetiap numpus berwarna merah.\nFae adalah tembus pandang\n\n**Jawaban**: False \n###\n\n------\n\n\nContoh:\n\nKonteks:\nWumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.\n\nPertanyaan:\nAlex oranye\n\n###\n**Penjelasan**:\nAlex adalah wumpus.\nWumpuses adalah yumpuses.\nAlex adalah yumpus\nSetiap yumpus berwarnya oranye.\nAlex berwarna oranye.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus a ...
# Saving result with thread lock in path:  results_translated_naive_prompting/prompt_explanations_before_answer\ProntoQA\LLM_MODELS_llama3-8b-cpt-sahabatai-v1-instruct_naive_prompting.json
# g:\Documents\Schools\University\UI\Sem_12\TA\Aristotle\venv\lib\site-packages\setuptools\_distutils\_msvccompiler.py:12: UserWarning: _get_vc_env is private; find an alternative (pypa/distutils#340)
#   warnings.warn(
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:02<00:07,  2.54s/it]
#
# Loading checkpoint shards:  50%|█████     | 2/4 [00:05<00:05,  2.56s/it]
#
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:07<00:02,  2.58s/it]
#
# Loading checkpoint shards: 100%|██████████| 4/4 [00:08<00:00,  1.73s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:08<00:00,  2.04s/it]
#
# 100%|██████████| 1/1 [12:33<00:00, 753.13s/it]
# 100%|██████████| 1/1 [12:33<00:00, 753.13s/it]

# %%
# !python evaluate.py --dataset_name ProntoQA --save_path results_translated_naive_prompting/prompt_explanations_before_answer --model_name $LLM_MODEL --evaluation_method naive_prompting
# Out:
# Loading exllamav2_ext extension (JIT)...
#
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Evaluating using the naive prompting method.
# Counter: 3
# ID: ProntoQA_1, GT: B, Negated: B, Non-negated: B
# ID: ProntoQA_2, GT: A, Negated: A, Non-negated: A
# Total instances: 2
# Accuracy: 100.00%
# Error id:  []
# Correct id:  ['ProntoQA_1', 'ProntoQA_2']
# Saved table image to: results_translated_naive_prompting/prompt_explanations_before_answer\ProntoQA\LLM_MODELS_llama3-8b-cpt-sahabatai-v1-instruct_results_table.png
# g:\Documents\Schools\University\UI\Sem_12\TA\Aristotle\venv\lib\site-packages\setuptools\_distutils\_msvccompiler.py:12: UserWarning: _get_vc_env is private; find an alternative (pypa/distutils#340)
#   warnings.warn(

# %%
# # Setting to vllm backend
# os.environ["LLM_BACKEND"] = "vllm"

# snapshot_path = "LLM_MODELS/llama3-8b-cpt-sahabatai-v1-instruct"
# #snapshot_path = "/workspace/LLM_MODELS/Llama-SEA-LION-v3-8B-IT"

# os.environ["LOCAL_MODEL_PATH"] = snapshot_path
# os.environ["LLM_MODEL"] = snapshot_path
# os.environ["QUANTIZATION"] = "fp8"

# print("LOCAL_MODEL_PATH =", os.environ["LOCAL_MODEL_PATH"])
# print("LLM_MODEL =", os.environ["LLM_MODEL"])

# ### If kernel doesnt recognize
# LLM_MODEL=snapshot_path
# LOCAL_MODEL_PATH=snapshot_path

# %%
# # Solving with naive prompting with explanations with vllm backend
# !python naive_prompting.py --data_path results_bahasa_translation --dataset_name ProntoQA --sample_pct 0 --prompts_folder manual_prompts_translated --prompts_file naive_prompting_explanations_before_answer --split dev --save_path results_translated_naive_prompting/prompt_explanations_before_answer --model_name $LLM_MODEL --batch_num $BATCH_NUM --max_new_tokens $MAX_NEW_TOKENS

# %%
# !python evaluate.py --dataset_name ProntoQA --save_path results_translated_naive_prompting/prompt_explanations_before_answer --model_name $LLM_MODEL --evaluation_method naive_prompting

# %%
# Setting to llamacpp backend
os.environ["LLM_BACKEND"] = "llamacpp"

snapshot_path = "LLM_MODELS_GGUF/SahabatAI/llama3-8b-cpt-sahabatai-v1-instruct-q4_k_m.gguf"
#snapshot_path = "/workspace/LLM_MODELS_EXL2/Llama-SEA-LION-v3-8B-IT-EXL2-Indonesia-Focus"

os.environ["LOCAL_MODEL_PATH"] = snapshot_path
os.environ["LLM_MODEL"] = snapshot_path

######## enable 4-bit for quants (and bitsandbytes is set up)
print("LOCAL_MODEL_PATH =", os.environ["LOCAL_MODEL_PATH"])
print("LLM_MODEL =", os.environ["LLM_MODEL"])

### If kernel doesnt recognize
LLM_MODEL=snapshot_path
LOCAL_MODEL_PATH=snapshot_path
# Out:
# LOCAL_MODEL_PATH = LLM_MODELS_GGUF/SahabatAI/llama3-8b-cpt-sahabatai-v1-instruct-q4_k_m.gguf
# LLM_MODEL = LLM_MODELS_GGUF/SahabatAI/llama3-8b-cpt-sahabatai-v1-instruct-q4_k_m.gguf

# %%
# Solving with naive prompting with explanations with llamacpp backend
# !python naive_prompting.py --data_path results_bahasa_translation --dataset_name ProntoQA --sample_pct 0 --prompts_folder manual_prompts_translated --prompts_file naive_prompting_explanations_before_answer --split dev --save_path results_translated_naive_prompting/prompt_explanations_before_answer --model_name $LLM_MODEL --batch_num $BATCH_NUM --max_new_tokens $MAX_NEW_TOKENS
# Out:
# Loading exllamav2_ext extension (JIT)...
#
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Loading translation file:  manual_prompts_translated\ProntoQA\naive_prompting_explanations_before_answer.txt
# SAMPLE PCT: 0
# START INDEX: None type: <class 'NoneType'>
# Loaded 1 examples from dev split.
# Number of batch:  1
# Running example id:  ProntoQA_1
#
# Naive prompting: Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
#
# --- Loading Model: LLM_MODELS_GGUF/SahabatAI/llama3-8b-cpt-sahabatai-v1-instruct-q4_k_m.gguf (llamacpp) ---
#
# Naive prompting response: [SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.
#
# [USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.
#
# ------
#
# Contoh:
#
# Konteks:
# Impuses adalah besar. Alex adalah impus.
#
# Pertanyaan:
# Alex besar
#
# ###
# **Penjelasan**:
# Alex adalah impus.
# Impuses adalah besar.
# Alex adalah besar.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap numpus adalah tembus pandang. Fae adalah numpus.
#
# Pertanyaan:
# Fae tidak tembus pandang
#
# ###
# **Penjelasan**:
# Fae adalah numpus.
# Setiap numpus berwarna merah.
# Fae adalah tembus pandang
#
# **Jawaban**: False
# ###
#
# ------
#
#
# Contoh:
#
# Konteks:
# Wumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.
#
# Pertanyaan:
# Alex oranye
#
# ###
# **Penjelasan**:
# Alex adalah wumpus.
# Wumpuses adalah yumpuses.
# Alex adalah yumpus
# Setiap yumpus berwarnya oranye.
# Alex berwarna oranye.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Setiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rompus bukan benda yang tidak tembus cahaya. Setiap rompus adalah vumpuses. Vumpuses bukanlah yang mudah dikelola. Vumpuses adalah jompus. Jompuses bukanlah pedas. Jompus adalah wumpus. Rex adalah vumpus.
#
# Pertanyaan:
# Rex tembus cahaya.
#
# ###
# **Penjelasan**:
# Rex adalah vumpus.
# Vumpuses adalah jompus.
# Jompus adalah wumpus.
# Rex adalah wumpus.
# Wumpus adalah numpus.
# Rex adalah numpus.
# Setiap numpus adalah dumpus.
# Rex adalah dumpus.
# Setiap dumpus adalah rompus.
# Rex adalah rompus.
# Setiap rompus bukan benda yang tidak tembus cahaya.
# Rex tembus cahaya.
#
# **Jawaban**: True
# ###
#
# ------
#
# Contoh:
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpuses.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpuses.
# Max juga tumpus
# Tumpuses tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
# ------
#
# Di bawah ini yang perlu Anda cari nilai kebenarannya:
#
# Konteks:
# Jompuses tidak pemalu. Jompuses adalah yumpuses. Setiap yumpus agresif. Setiap yumpus adalah dumpus. Dumpuses tidak kayu. Dumpuses adalah wumpuses. Wumpuses merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tanah. Setiap vumpus adalah zumpus. Zumpuses kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**: Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpus.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpus.
# Max juga tumpus
# Tumpus tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpus.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max tidak tembus pandang.
# Impuses adalah tumpus.
# Max juga tumpus
# Tumpus tidak asam.
# Max tidak asam.
#
# **Jawaban**: False
# ###
#
#
# Konteks:
# Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.
#
# Pertanyaan:
# Max asam.
#
# ###
# **Penjelasan**:
# Max adalah yumpus.
# Setiap yumpus adalah dumpus.
# Max adalah dumpus.
# Dumpuses adalah wumpus.
# Max adalah wumpus.
# Setiap wumpus adalah impus.
# Max adalah impus.
# Setiap impus tidak tembus pandang.
# Max
#
# Extracted answer:  False
# Extracted explanations:  ['Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpus.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpus.', 'Max juga tumpus', 'Tumpus tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**:', 'Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpus.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpus.', 'Max juga tumpus', 'Tumpus tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**:', 'Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpus.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max']
# Saving output for record: {'id': 'ProntoQA_1', 'answer': 'False', 'final_choice': 'B', 'explanations': ['Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpus.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpus.', 'Max juga tumpus', 'Tumpus tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**:', 'Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpus.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max tidak tembus pandang.', 'Impuses adalah tumpus.', 'Max juga tumpus', 'Tumpus tidak asam.', 'Max tidak asam.', 'Jawaban**: False', '###', 'Konteks:', 'Jompuses bukan pemalu. Jompuses adalah yumpuses. Setiap yumpus bersifat agresif. Setiap yumpus adalah dumpus. Dumpuses bukan terbuat dari kayu. Dumpuses adalah wumpuses. Wumpuses berwarna merah. Setiap wumpus adalah impus. Setiap impus tidak tembus pandang. Impuses adalah tumpuses. Numpuses asam. Tumpuses tidak asam. Tumpuses adalah vumpuses. Vumpuses tidak terbuat tanah. Setiap vumpus adalah zumpus. Zumpuses berukuran kecil. Zumpuses adalah rompuses. Max adalah yumpus.', 'Pertanyaan:', 'Max asam.', '###', 'Penjelasan**:', 'Max adalah yumpus.', 'Setiap yumpus adalah dumpus.', 'Max adalah dumpus.', 'Dumpuses adalah wumpus.', 'Max adalah wumpus.', 'Setiap wumpus adalah impus.', 'Max adalah impus.', 'Setiap impus tidak tembus pandang.', 'Max'], 'ground_truth': 'B', 'response': '[SYSTEM] Anda adalah asisten yang cerdas dan sangat membantu dan diakui sebagai salah satu ilmuwan AI, ahli logika, dan matematikawan terbaik serta selalu menjawab dalam Bahasa Indonesia yang baik dan benar. Sebelum mulai menyelesaikan masalah, pastikan Anda memahami secara cermat dan menyeluruh setiap detail kebutuhan pengguna.\n\n[USER] Deskripsi Tugas: Anda diberikan sebuah konteks yang berisi sekumpulan premis dan pertanyaan mengenai konteks tersebut. Tugas Anda adalah menjawab pertanyaan tersebut dengan memilih salah satu nilai kebenaran True atau False berdasarkan konteks yang diberikan dengan memberikan penjelasan langkah-langkah yang Anda gunakan untuk mencapai nilai kebenaran/jawaban tersebut.\n\n------\n\nContoh:\n\nKonteks:\nImpuses adalah besar. Alex adalah impus.\n\nPertanyaan:\nAlex besar\n\n###\n**Penjelasan**:\nAlex adalah impus.\nImpuses adalah besar.\nAlex adalah besar.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap numpus adalah tembus pandang. Fae adalah numpus.\n\nPertanyaan:\nFae tidak tembus pandang\n\n###\n**Penjelasan**:\nFae adalah numpus.\nSetiap numpus berwarna merah.\nFae adalah tembus pandang\n\n**Jawaban**: False \n###\n\n------\n\n\nContoh:\n\nKonteks:\nWumpuses adalah besar.  Wumpuses adalah yumpuses. Setiap yumpus berwarna oranye. Alex adalah wumpus.\n\nPertanyaan:\nAlex oranye\n\n###\n**Penjelasan**:\nAlex adalah wumpus.\nWumpuses adalah yumpuses.\nAlex adalah yumpus\nSetiap yumpus berwarnya oranye.\nAlex berwarna oranye.\n\n**Jawaban**: True \n###\n\n------\n\nContoh:\n\nKonteks:\nSetiap impus bukanlah panas. Setiap impus adalah wumpus. Wumpuses adalah temperamen. Wumpus adalah numpus. Zumpus adalah tidak bersifat agresif. Numpuses adalah bukan suku yang temperate. Setiap numpus adalah dumpus. Dumpuses adalah baik. Setiap dumpus adalah rompus. Setiap rom ...
# Saving result with thread lock in path:  results_translated_naive_prompting/prompt_explanations_before_answer\ProntoQA\LLM_MODELS_GGUF_SahabatAI_llama3-8b-cpt-sahabatai-v1-instruct-q4_k_m.gguf_naive_prompting.json
# g:\Documents\Schools\University\UI\Sem_12\TA\Aristotle\venv\lib\site-packages\setuptools\_distutils\_msvccompiler.py:12: UserWarning: _get_vc_env is private; find an alternative (pypa/distutils#340)
#   warnings.warn(
# llama_context: n_ctx_per_seq (4096) < n_ctx_train (8192) -- the full capacity of the model will not be utilized

# %%
# !python evaluate.py --dataset_name ProntoQA --save_path results_translated_naive_prompting/prompt_explanations_before_answer --model_name $LLM_MODEL --evaluation_method naive_prompting
# Out:
# Loading exllamav2_ext extension (JIT)...
#
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Building C++/CUDA extension ------------------------------   0% 0:00:00 -:--:--
# Evaluating using the naive prompting method.
# Counter: 1
# ID: ProntoQA_1, GT: B, Negated: B, Non-negated: B
# Total instances: 1
# Accuracy: 100.00%
# Error id:  []
# Correct id:  ['ProntoQA_1']
# Saved table image to: results_translated_naive_prompting/prompt_explanations_before_answer\ProntoQA\LLM_MODELS_GGUF_SahabatAI_llama3-8b-cpt-sahabatai-v1-instruct-q4_k_m.gguf_results_table.png
# g:\Documents\Schools\University\UI\Sem_12\TA\Aristotle\venv\lib\site-packages\setuptools\_distutils\_msvccompiler.py:12: UserWarning: _get_vc_env is private; find an alternative (pypa/distutils#340)
#   warnings.warn(
